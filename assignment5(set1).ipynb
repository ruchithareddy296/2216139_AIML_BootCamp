# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchithareddy296/2216139_AIML_BootCamp/blob/main/assignment5(set1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#initiaize the list elements
data=[0.2,0.4,0.6,0.8]
df=pd.DataFrame(data,columns=["bateria_size"])
df["max_growth"]=[3.4,3.8,4.2,4.6]
df
# Out:
#    bateria_size  max_growth
# 0           0.2         3.4
# 1           0.4         3.8
# 2           0.6         4.2
# 3           0.8         4.6

# %%
x_train=df.iloc[:3,:-1]
y_train=df.iloc[:3,-1:]
x_test=df.iloc[3:,:-1]
y_test=df.iloc[3:,-1:]

# %%
x_train
# Out:
#    bateria_size
# 0           0.2
# 1           0.4
# 2           0.6

# %%
y_train
# Out:
#    max_growth
# 0         3.4
# 1         3.8
# 2         4.2

# %%
x_test
# Out:
#    bateria_size
# 3           0.8

# %%
y_test
# Out:
#    max_growth
# 3         4.6

# %%
import sympy as sym
from sympy import *

# %%
#step1:Initialize model parameters
mi = 1                                                                            
ci = -1
n = 0.01
epochs = 50
y=1
x=1
m=1
c=1

iter = 1
ns = len(x_train)
 
# Step2: Start iteration
for iter in range(1,epochs+1):
  
  print("Iteration : {}".format(iter))
  print('++++++++++++++++++++++++++++')
  #step3: track samples
  for sample in range(0,ns):
    xa = x_train['bateria_size'][sample] #0.2
    ya = y_train['max_growth'][sample] #3.4
    print("-->sample {}".format(sample+1)+" x={}".format(xa)+" y={}".format(ya))

    #step 4:Calculate the Gradient
    E = (0.5) *(y-m*x-c)**2 #error Function
    x = sym.Symbol('x')
    y = sym.Symbol('y')
    m = sym.Symbol('m')
    c = sym.Symbol('c')

    deltaE_m = sym.diff(E,m)
    deltaE_c = sym.diff(E,c)

    #substituting values
    deltaE_m=deltaE_m.subs(m,mi)
    deltaE_m=deltaE_m.subs(c,ci)
    deltaE_m=deltaE_m.subs(x,xa)
    deltaE_m=deltaE_m.subs(y,ya)

    deltaE_c=deltaE_c.subs(m,mi)
    deltaE_c=deltaE_c.subs(c,ci)
    deltaE_c=deltaE_c.subs(x,xa)
    deltaE_c=deltaE_c.subs(y,ya)

    print('deltaE_m:',deltaE_m)
    print('deltaE_c',deltaE_c)

    #Step5: Calculate step length
    del_m=-n*deltaE_m
    del_c=-n*deltaE_c

    #step6:Updating model parameters
    mi=mi+del_m
    ci=ci+del_c
    print("m:{}".format(mi))
    print("c:{}".format(ci))

print('++++++++++++++++++++++++++++++++++++++')
print('Optimal Values:')
print("m:{}".format(mi))
print("c:{}".format(ci))
# Out:
# Iteration : 1
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: 0
# deltaE_c 0
# m:1
# c:-1
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -1.76000000000000
# deltaE_c -4.40000000000000
# m:1.01760000000000
# c:-0.956000000000000
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -2.72726400000000
# deltaE_c -4.54544000000000
# m:1.04487264000000
# c:-0.910545600000000
# Iteration : 2
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.820314214400000
# deltaE_c -4.10157107200000
# m:1.05307578214400
# c:-0.869529889280000
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -1.69931983056896
# deltaE_c -4.24829957642240
# m:1.07006898044969
# c:-0.827046893515776
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -2.63100330314758
# deltaE_c -4.38500550524596
# m:1.09637901348117
# c:-0.783196838463316
# Iteration : 3
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.555035968699024
# deltaE_c -0.925059947831707
# m:2.20012642149789
# c:1.96744501456007
# Iteration : 45
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.198505940228070
# deltaE_c -0.992529701140350
# m:2.20211148090017
# c:1.97737031157148
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.376714038427383
# deltaE_c -0.941785096068457
# m:2.20587862128444
# c:1.98678816253216
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.533810798818305
# deltaE_c -0.889684664697175
# m:2.21121672927263
# c:1.99568500917913
# Iteration : 46
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.192414328993269
# deltaE_c -0.962071644966343
# m:2.21314087256256
# c:2.00530572562880
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.363775170138473
# deltaE_c -0.909437925346182
# m:2.21677862426394
# c:2.01440010488226
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.513319632335627
# deltaE_c -0.855532720559378
# m:2.22191182058730
# c:2.02295543208785
# Iteration : 47
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.186532440758938
# deltaE_c -0.932662203794690
# m:2.22377714499489
# c:2.03228205412580
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.351282835150499
# deltaE_c -0.878207087876247
# m:2.22728997334639
# c:2.04106412500456
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.493537134592562
# deltaE_c -0.822561890987604
# m:2.23222534469232
# c:2.04928974391444
# Iteration : 48
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.180853037429420
# deltaE_c -0.904265187147100
# m:2.23403387506661
# c:2.05833239578591
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.339221621674979
# deltaE_c -0.848054054187447
# m:2.23742609128336
# c:2.06681293632778
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.474438845341321
# deltaE_c -0.790731408902201
# m:2.24217047973678
# c:2.07472025041680
# Iteration : 49
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.175369130727168
# deltaE_c -0.876845653635841
# m:2.24392417104405
# c:2.08348870695316
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.327576649851687
# deltaE_c -0.818941624629218
# m:2.24719993754256
# c:2.09167812319945
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.456001148565004
# deltaE_c -0.760001914275007
# m:2.25175994902821
# c:2.09927814234220
# Iteration : 50
# ++++++++++++++++++++++++++++
# -->sample 1 x=0.2 y=3.4
# deltaE_m: -0.170073973570430
# deltaE_c -0.850369867852152
# m:2.25346068876392
# c:2.10778184102073
# -->sample 2 x=0.4 y=3.8
# deltaE_m: -0.316333553389482
# deltaE_c -0.790833883473706
# m:2.25662402429781
# c:2.11569017985546
# -->sample 3 x=0.6 y=4.2
# deltaE_m: -0.438201243339509
# deltaE_c -0.730335405565849
# m:2.26100603673121
# c:2.12299353391112
# ++++++++++++++++++++++++++++++++++++++
# Optimal Values:
# m:2.26100603673121
# c:2.12299353391112

# %%
#y =1.77x+0.99 --> BestFit Line
y_train_pred=[]
for i in range(0,len(x_train)):
  y_cal = mi*x_train['bateria_size'][i]+ci
  y_train_pred.append(y_cal)
y_train_pred
# Out:
# [2.57519474125736, 3.02739594860361, 3.47959715594985]

# %%
y_train_list = list(y_train['max_growth'])
y_train_list
# Out:
# [3.4, 3.8, 4.2]

# %%
x_train_list=list(x_train['bateria_size'])
x_train_list
# Out:
# [0.2, 0.4, 0.6]

# %%
Error=[]
for i in range(0,len(x_train)):
  err=(y_train_list[i]-y_train_pred[i])
  Error.append(err)
Error
# Out:
# [0.824805258742636, 0.772604051396395, 0.720402844050153]

# %%
import matplotlib.pyplot as plt
plt.plot(x_train_list,y_train_list,label='y_train',color='green')
plt.plot(x_train_list,y_train_pred,label='y_predicted',color='red')

plt.title('Visualising the Training Error')
plt.xlabel('x values')
plt.ylabel('y values')

plt.show()
